# %%
SK learn
Data from Kaggle
https://www.kaggle.com/datasets/adepvenugopal/height-weight-gender?select=heights_weights.csv
10000 people. Heights and Weights.
predict gender based on height and weight.
92% accurate

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import time
import sklearn.neighbors as nei

df = pd.read_csv('heights_weights.csv')

print(df.tail())

sns.pairplot(df, hue='Gender')
# Out:
#          Height      Weight  Gender
# 9995  66.172652  136.777454       0
# 9996  67.067155  170.867906       0
# 9997  63.867992  128.475319       0
# 9998  69.034243  163.852461       0
# 9999  61.944246  113.649103       0

# %%
knn = nei.KNeighborsClassifier(n_neighbors=5)

# %%
##inputs and outputs
inputs = df[['Height', 'Weight']]
outputs = df['Gender']

knn.fit(inputs, outputs)
outputs
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9995    0
# 9996    0
# 9997    0
# 9998    0
# 9999    0
# Name: Gender, Length: 10000, dtype: int64

# %%
#classifier
knn = nei.KNeighborsClassifier(n_neighbors=5)

# %%
##fit
knn.fit(inputs, outputs)
# Out:
# KNeighborsClassifier()

# %%
##predict
df.loc[0]
# Out:
# Height     73.847017
# Weight    241.893563
# Gender      1.000000
# Name: 0, dtype: float64

# %%
knn.predict([[73.85,241.9],[73.85,241.9]])
# Out:
# array([1, 1], dtype=int64)

# %%
##evaluate
knn.predict(inputs)
# Out:
# array([1, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
knn.predict(inputs)==outputs
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 9995     True
# 9996    False
# 9997     True
# 9998     True
# 9999     True
# Name: Gender, Length: 10000, dtype: bool

# %%
(knn.predict(inputs)==outputs).sum()
# Out:
# 9287
