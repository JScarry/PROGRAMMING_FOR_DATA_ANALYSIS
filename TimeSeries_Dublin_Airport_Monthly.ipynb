# %%
#Dublin airport rainfall dataset

# %%
import pandas as pd
from datetime import date

# %%
df = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/mly532.csv", skiprows=19, low_memory=False) #nrows=100
#df_index = pd.read_csv("https://cli.fusio.net/cli/climate_data/webdata/mly532.csv", nrows=20)
#df_index
df
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain   gmin  wdsp maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9   67.2   -5.7  12.0
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9   41.7   -7.6  12.5
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7   91.9   -9.5  13.1
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0   25.8  -10.7   9.0
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2   76.4   -8.3  10.7
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 966  2022      6   13.6   22.6    2.3   17.7    9.5   43.6   -2.1   8.3    33
# 967  2022      7   16.3   29.1    6.6   21.0   11.7   29.6    0.0   8.1    33
# 968  2022      8   15.9   26.3    6.0   21.3   10.5   34.6    0.9   7.3    30
# 969  2022      9   13.0   20.1    3.1   17.2    8.8  127.9   -0.3   8.7    39
# 970  2022     10   12.0   18.0    1.3   15.6    8.4  106.8   -3.3   9.6    41
#
#        sun
# 0     56.1
# 1     46.1
# 2     72.8
# 3     51.4
# ...

# %%
df['date_time'] = pd.to_datetime(df[['year', 'month']].assign(DAY=1)) #Combine month year columns to a new timedate column. https://stackoverflow.com/questions/48304927/cleanly-combine-year-and-month-columns-to-single-date-column-with-pandas
df
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain   gmin  wdsp maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9   67.2   -5.7  12.0
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9   41.7   -7.6  12.5
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7   91.9   -9.5  13.1
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0   25.8  -10.7   9.0
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2   76.4   -8.3  10.7
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 966  2022      6   13.6   22.6    2.3   17.7    9.5   43.6   -2.1   8.3    33
# 967  2022      7   16.3   29.1    6.6   21.0   11.7   29.6    0.0   8.1    33
# 968  2022      8   15.9   26.3    6.0   21.3   10.5   34.6    0.9   7.3    30
# 969  2022      9   13.0   20.1    3.1   17.2    8.8  127.9   -0.3   8.7    39
# 970  2022     10   12.0   18.0    1.3   15.6    8.4  106.8   -3.3   9.6    41
#
#        sun  date_time
# 0     56.1 1941-11-01
# ...

# %%
df['date_ordinal'] = pd.to_datetime(df['date_time']).apply(lambda date: date.toordinal())
df
# Out:
#      year  month  meant  maxtp  mintp  mnmax  mnmin   rain   gmin  wdsp maxgt  \
# 0    1941     11    6.9   14.0   -3.1    9.9    3.9   67.2   -5.7  12.0
# 1    1941     12    6.5   12.7   -3.6    9.1    3.9   41.7   -7.6  12.5
# 2    1942      1    4.3   11.9   -3.1    6.9    1.7   91.9   -9.5  13.1
# 3    1942      2    2.9   11.6   -4.3    5.8   -0.0   25.8  -10.7   9.0
# 4    1942      3    6.3   16.2   -6.1    9.4    3.2   76.4   -8.3  10.7
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...   ...   ...
# 966  2022      6   13.6   22.6    2.3   17.7    9.5   43.6   -2.1   8.3    33
# 967  2022      7   16.3   29.1    6.6   21.0   11.7   29.6    0.0   8.1    33
# 968  2022      8   15.9   26.3    6.0   21.3   10.5   34.6    0.9   7.3    30
# 969  2022      9   13.0   20.1    3.1   17.2    8.8  127.9   -0.3   8.7    39
# 970  2022     10   12.0   18.0    1.3   15.6    8.4  106.8   -3.3   9.6    41
#
#        sun  date_time  date_ordinal
# ...

# %%
#seaborn lineplot
import seaborn as sns
sns.lineplot(data=df[0:], x="date_time", y="rain")
#sns.regplot(data=df[0:], x="date_ordinal", y="rain")
# Out:
# <AxesSubplot:xlabel='date_time', ylabel='rain'>

# %%
#seaborn lineplot regression line. Date_ordinal added to df. X axis label changed
import seaborn as sns
title = 'Dublin Airport monthly mean temperature 1941-2022'
ax = sns.set(rc={"figure.figsize":(12, 10)}) #width=6, height=5 #set size of plot
ax = sns.lineplot(data=df[0:], x="date_ordinal", y="meant").set(title= title )
ax = sns.regplot(data=df[0:], x="date_ordinal", y="meant")
ax.set_xlabel('date_time')
new_labels = [date.fromordinal(int(item)) for item in ax.get_xticks()]
ax.set_xticklabels(new_labels)
# Out:
# C:\Users\JS\AppData\Local\Temp/ipykernel_11116/3256654939.py:9: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(new_labels)
# [Text(705000.0, 0, '1931-03-24'),
#  Text(710000.0, 0, '1944-11-30'),
#  Text(715000.0, 0, '1958-08-09'),
#  Text(720000.0, 0, '1972-04-17'),
#  Text(725000.0, 0, '1985-12-25'),
#  Text(730000.0, 0, '1999-09-03'),
#  Text(735000.0, 0, '2013-05-12'),
#  Text(740000.0, 0, '2027-01-19')]

# %%
#plt plot
import matplotlib.pyplot as plt
#df.plot(kind='line',x='name',y='num_children',ax=ax)
df.plot(x="date_time", y="meant")
#sns.regplot(data=df[0:], x="date_ordinal", y="meant")
# Out:
# <AxesSubplot:xlabel='date_time'>
